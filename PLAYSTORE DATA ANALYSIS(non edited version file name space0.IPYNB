# %% [markdown]
# ## PLAYSTORE DATA ANALYSIS

# %% [markdown]
# ## LOADING DATA
#
# - Pandas</span>
#   <span style="color:#1d6fa5;">is used for data manipulation.</span>
#
# - <span style="color:#2a6f97;">Matplotlib and Seaborn</span>
#   <span style="color:#1d6fa5;">are used for data visualization.</span>

# %%
import pandas as pd  
df=pd.read_csv("data2 playstore.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("data2 playstore.csv")
#       3 df
#
# File c:\Users\INTERN\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ## <span style="color:#0B3C5D; font-weight:600;">INSPECTION OF DATA</span>

# %% [markdown]
# - <span style="color:#0077b6;"><code>df.head()</code></span>
#   <span style="color:#1d6fa5;">returns the top 5 rows by default.</span> If a specific number is given inside the parentheses, it returns that many rows from the top of the table.

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.head(15)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %% [markdown]
# - ##### df.tail():-to show the last 5 rows of the table simply the tail of the table,also if we give specific number on the parenthesis it will show that much rows from the tail of the table or the bottom of the table

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.tail(12)
# Out:
#                                                  App             Category  \
# 10829                 Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                              News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - ##### df.sample(n):-used to display n number of random rows from the dataframe

# %%
df.sample()
# Out:
#                                      App Category  Rating Reviews  \
# 491  Hot or Not - Find someone right now   DATING     4.1  305708
#
#                    Size     Installs  Type Price Content Rating  Genres  \
# 491  Varies with device  10,000,000+  Free     0     Mature 17+  Dating
#
#        Last Updated         Current Ver         Android Ver
# 491  August 2, 2018  Varies with device  Varies with device

# %%
df.sample(10)
# Out:
#                                                      App             Category  \
# 7067                             ePN Cashback AliExpress             SHOPPING
# 2308                                      Teladoc Member              MEDICAL
# 10217                      MultiMessage for FB Messenger         PRODUCTIVITY
# 572                    SilverSingles: The 50+ Dating App               DATING
# 8745                                       World Webcams              WEATHER
# 8463                       Euro Truck Driver (Simulator)               FAMILY
# 5031                       Connect.ae - Local Search UAE     TRAVEL_AND_LOCAL
# 8343                                   Red Transporte DF  MAPS_AND_NAVIGATION
# 8492                             Salah Widget (DK+Malmo)            LIFESTYLE
# 8004   20WPM Amateur ham radio Koch CW Morse code tra...        COMMUNICATION
#
#        Rating Reviews                Size     Installs  Type  Price  \
# ...

# %% [markdown]
# - ##### df.types:-used to display the data types of the columns of the table or data frames

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# -  ##### df.columns:-used to display the column names

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# - ##### df.shape:-used to display number of rows and columns

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# - ##### df.info():-used to display the basic information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# - ##### From the analysis, the above data has 5 columns with missing values they are:
#
#   - Rating:- 1474 missing values
#   - Type:- 1 missing value</span>
#   - Content Rating:- 1 missing value</span>
#   - Current Version:- 7</span>
#   - Android Version:- 3 missing values</span>

# %% [markdown]
# - #### EDA Exploratory Data Analysis

# %% [markdown]
# - ##### df['']:-selecting a single coloumn
# - ##### df[['rating','type']]:-To select multiple coloumns

# %%
df['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
df[['Type','App']]
# Out:
#        Type                                                App
# 0      Free     Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Free                                Coloring book moana
# 2      Free  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3      Free                              Sketch - Draw & Paint
# 4      Free              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 10836  Free                                   Sya9a Maroc - FR
# 10837  Free                   Fr. Mike Schmitz Audio Teachings
# 10838  Free                             Parkinson Exercices FR
# 10839  Free                      The SCP Foundation DB fr nn5n
# 10840  Free      iHoroscope - 2018 Daily Horoscope & Astrology
#
# [10841 rows x 2 columns]

# %% [markdown]
# - #### Creating a new DataFrame using the columns of the previous DataFrame

# %%
df[['App','Rating','Type']]
# Out:
#                                                      App  Rating  Type
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     4.1  Free
# 1                                    Coloring book moana     3.9  Free
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7  Free
# 3                                  Sketch - Draw & Paint     4.5  Free
# 4                  Pixel Draw - Number Art Coloring Book     4.3  Free
# ...                                                  ...     ...   ...
# 10836                                   Sya9a Maroc - FR     4.5  Free
# 10837                   Fr. Mike Schmitz Audio Teachings     5.0  Free
# 10838                             Parkinson Exercices FR     NaN  Free
# 10839                      The SCP Foundation DB fr nn5n     4.5  Free
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     4.5  Free
#
# [10841 rows x 3 columns]

# %% [markdown]
# - ## <span style="color:#0b3c5d;">Filtering</span>

# %% [markdown]
# #### We can use filtering methods to filter data according to our needs
# - #### df[df[]]

# %%
df[df['Rating']>4.5]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %%
df[df['Genres']=="Education"]
# Out:
#                                                      App   Category  Rating  \
# 700                                                  TED  EDUCATION     4.6
# 701    English Communication - Learn English for Chin...  EDUCATION     4.7
# 702                                         Khan Academy  EDUCATION     4.6
# 703                           Learn English with Wlingua  EDUCATION     4.7
# 704                          Ai La Trieu Phu - ALTP Free  EDUCATION     NaN
# ...                                                  ...        ...     ...
# 10820                                    Fr. Daoud Lamei     FAMILY     5.0
# 10827                                 Fr Agnel Ambarnath     FAMILY     4.2
# 10834                                      FR Calculator     FAMILY     4.0
# 10836                                   Sya9a Maroc - FR     FAMILY     4.5
# 10837                   Fr. Mike Schmitz Audio Teachings     FAMILY     5.0
#
# ...

# %%
df[df['Category']=='FAMILY']
# Out:
#                                     App Category  Rating  Reviews  \
# 2014                       YouTube Kids   FAMILY     4.5   470694
# 2015                         Candy Bomb   FAMILY     4.4    42145
# 2016                             ROBLOX   FAMILY     4.5  4449910
# 2017       Jewels Crush- Match 3 Puzzle   FAMILY     4.4    14774
# 2018                   Coloring & Learn   FAMILY     4.4    12753
# ...                                 ...      ...     ...      ...
# 10821                           Poop FR   FAMILY     NaN        6
# 10827                Fr Agnel Ambarnath   FAMILY     4.2      117
# 10834                     FR Calculator   FAMILY     4.0        7
# 10836                  Sya9a Maroc - FR   FAMILY     4.5       38
# 10837  Fr. Mike Schmitz Audio Teachings   FAMILY     5.0        4
#
#                      Size      Installs  Type Price Content Rating  \
# 2014   Varies with device   50,000,000+  Free     0       Everyone
# ...

# %%
df[df['Type']=='Free']
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df['Reviews']>'9000']
# Out:
#                                           App           Category  Rating  \
# 1                         Coloring book moana     ART_AND_DESIGN     3.9
# 4       Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN     4.3
# 78                        Best Car Wallpapers  AUTO_AND_VEHICLES     4.5
# 106                     Tie - Always be happy             BEAUTY     4.7
# 119    Mirror Camera (Mirror + Selfie Camera)             BEAUTY     4.1
# ...                                       ...                ...     ...
# 10747                    FP Charging Daydream    PERSONALIZATION     3.5
# 10763                     FP Разбитый дисплей             FAMILY     4.5
# 10778                            Union League             FAMILY     4.0
# 10808                      lesparticuliers.fr          LIFESTYLE     NaN
# 10818                    Gold Quote - Gold.fr            FINANCE     NaN
#
#       Reviews  Size    Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# - ### Multiple Filtering

# %%
df[(df['Rating']>4.5) & (df['Type']=='Free')]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %% [markdown]
# - #### Filtered the data using two specifications the apps with rating abiove 4.5 and free to use

# %% [markdown]
# - ## <span style="color:#0b3c5d;">Selecting Rows</span>

# %% [markdown]
# - ### <span style="color:#0b3c5d;">Display the contents of a specified row</span>
#   <span style="color:#1d6fa5;">using position-based indexing</span>
#
# - ### <span style="color:#0b3c5d;"><code>df.iloc[]</code>, <code>df.iloc[:]</code></span>
#   <span style="color:#1d6fa5;">used to access rows and columns by integer positions</span>

# %%
df.iloc[10]
# Out:
# App               Text on Photo - Fonteee
# Category                   ART_AND_DESIGN
# Rating                                4.4
# Reviews                             13880
# Size                                  28M
# Installs                       1,000,000+
# Type                                 Free
# Price                                   0
# Content Rating                   Everyone
# Genres                       Art & Design
# Last Updated             October 27, 2017
# Current Ver                         1.0.4
# Android Ver                    4.1 and up
# Name: 10, dtype: object

# %%
df.iloc[12:19]
# Out:
#                                                 App        Category  Rating  \
# 12                   Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# 13                            Mandala Coloring Book  ART_AND_DESIGN     4.6
# 14  3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN     4.4
# 15                  Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2
# 16     Photo Designer - Write your name with shapes  ART_AND_DESIGN     4.7
# 17                         350 Diy Room Decor Ideas  ART_AND_DESIGN     4.5
# 18                    FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating        Genres  \
# 12   44829   20M  10,000,000+  Free     0           Teen  Art & Design
# 13    4326   21M     100,000+  Free     0       Everyone  Art & Design
# 14    1518   37M     100,000+  Free     0       Everyone  Art & Design
# 15      55  2.7M       5,000+  Free     0       Everyone  Art & Design
# ...

# %% [markdown]
# - ### Locate

# %% [markdown]
# - #### <span style="color:#0b3c5d;">Locate specific columns of a specific row</span>
#   <span style="color:#1d6fa5;">using label-based indexing in Pandas</span>
#
# - #### <span style="color:#0b3c5d;"><code>df.loc[]</code></span>
#   <span style="color:#1d6fa5;">used to access rows and columns using labels</span>

# %%
df.loc[2,'Rating']
# Out:
# np.float64(4.7)

# %% [markdown]
# - #### Renaming column name

# %% [markdown]
#    - #### df.rename(columns={"sex": "gender"})-rename only in this line
#    - #### df.rename(columns={"sex":"gender"},inplace=True):- rename the column title for the entire table permanently

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.rename(columns={"Current Ver":"Latest vers"})
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - #### without inplace:- changes for only one time

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.rename(columns={"Current Ver":"Latest vers"},inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# above, after using 'inplace=True' the column name completely changed from 'Current Ver' to 'Latest ver'

# %% [markdown]
# - ## df[].value_counts()

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df['Genres'].value_counts()
# Out:
# Genres
# Tools                     842
# Entertainment             623
# Education                 549
# Medical                   463
# Business                  460
#                          ...
# Arcade;Pretend Play         1
# Card;Brain Games            1
# Lifestyle;Pretend Play      1
# Comics;Creativity           1
# Strategy;Creativity         1
# Name: count, Length: 120, dtype: int64

# %% [markdown]
# - #### DATA CLEANING
#      - ##### cleaning the numerical columns with character

# %% [markdown]
#   - ##### #Remove text units and convert to numbers

# %%
df.head()  #displaying the table to check the columns with error or needs cleaning
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Latest vers  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10841, dtype: object

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: count, Length: 462, dtype: int64

# %%
df['Installs'] = pd.to_numeric(
    df['Installs']
    .astype(str)
    .str.replace(r'[+,]', '', regex=True),  # remove + and commas
    errors='coerce'
)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - #### after cleaning  we can see in the above table that the '+' in the install column as removed

# %% [markdown]
# - ##### now we can check after cleaning does the type and info changed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Latest vers     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# - ##### In the same way we can also change the other column and others needing changes
# - ##### we can see that in the price column dollar symbol $ is there so we are converting this to integer column by removing it.

# %%
df['Price']=pd.to_numeric(
    df['Price']
    .astype(str)
    .str.replace(r'[^0-9,-]','',regex=True),
    errors='coerce'
)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.sample(15)
#checking whether the price column changed
# Out:
#                                                     App         Category  \
# 5972                                         BC's Pizza        LIFESTYLE
# 601   Meet, chat & date. Free dating app - Chocolate...           DATING
# 7141                                            CB Land         BUSINESS
# 2096  My Oasis - Calming and Relaxing Idle Clicker Game           FAMILY
# 7608                       We Bare Bears Match3 Repairs           FAMILY
# 5142                           Denis Brogniart - AH 2 !           FAMILY
# 262                               ClickMeeting Webinars         BUSINESS
# 3020  CBS Sports App - Scores, News, Stats & Watch Live           SPORTS
# 7859                                  CT Abdomen Pelvis          MEDICAL
# 4695                          BTS V LINE Launcher theme  PERSONALIZATION
# 416                                     Ninesky Browser    COMMUNICATION
# 7329                                        Chrome Beta     PRODUCTIVITY
# ...

# %% [markdown]
# - #### Now we can consider the last updated column and make it as date and time datatype column

# %%
df['Last Updated']=pd.to_datetime(df["Last Updated"],errors="coerce")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - ## Dropping columns
# -  #### Now we are removing coloumns that are not needed for analysis

# %%
df.drop(columns=['Latest vers','Size'],inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - ## Handling missing values

# %%
df.isnull().sum() #finds the number of missing values
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Android Ver          3
# dtype: int64

# %% [markdown]
# - ### How to handle data
#      ##### For example consider a data with 1000 rows and 8 columns
#      ##### A- 900 missing -Since a lot of the values are missing in consideration with the total number of rows is 1000  in this column so we can drop this column(Also consider of the importance of the column in analysis before droping )
#      ##### B-12 :- fill if data is less or drop rows
#      ##### C- 0 :- No missing values
#      ##### D- 200 :- drop the row with columns having missing values if it is not relevant

# %% [markdown]
# - #### How to fill missing data
#    - ##### Numerical:- Fill with median
#    - ##### Categoriical:- Fill with mode

# %% [markdown]
# - ##### Filling With Median:-

# %%
# Filling With Median:- 
df['Rating'].fillna(df['Rating'].median(),inplace=True)
df.isnull().sum()
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_12628\2946229684.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].median(),inplace=True)
# App               0
# Category          0
# Rating            0
# Reviews           0
# Installs          1
# Type              1
# Price             1
# Content Rating    1
# Genres            0
# Last Updated      1
# Android Ver       3
# dtype: int64

# %% [markdown]
# - ##### Dropping Rows :-

# %% [markdown]
# - ##### We are dropping the columns such as Type,Price,Content Rating,Last Updated,Android Ver because they contain missing values

# %%
df.dropna(subset=['Type','Price','Content Rating','Last Updated','Android Ver'], inplace=True)

# %% [markdown]
# - ##### Checking whether the missing values dropped:-

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Android Ver       0
# dtype: int64

# %% [markdown]
# - ### Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
print('Before:',df.shape)
df=df.drop_duplicates()
print('After:',df.shape)
# Out:
# Before: (10837, 11)
# After: (10354, 11)

# %% [markdown]
# - ### checking whether its clean now

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10354 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10354 non-null  object
#  1   Category        10354 non-null  object
#  2   Rating          10354 non-null  float64
#  3   Reviews         10354 non-null  object
#  4   Installs        10354 non-null  float64
#  5   Type            10354 non-null  object
#  6   Price           10354 non-null  float64
#  7   Content Rating  10354 non-null  object
#  8   Genres          10354 non-null  object
#  9   Last Updated    10354 non-null  datetime64[ns]
#  10  Android Ver     10354 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 970.7+ KB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews    Installs  Type  Price Content Rating                     Genres  \
# 0     159     10000.0  Free    0.0       Everyone               Art & Design
# 1     967    500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 2   87510   5000000.0  Free    0.0       Everyone               Art & Design
# 3  215644  50000000.0  Free    0.0           Teen               Art & Design
# 4     967    100000.0  Free    0.0       Everyone    Art & Design;Creativity
#
#   Last Updated   Android Ver
# ...
